# %% [markdown]
# ## Socioeconomic Status Effect on Obesity
#
# - Average Obesity rate for the country of the dataset

# %%
# import necessaty libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')

# %%
dataset = pd.read_csv('Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv')
dataset.sample(5)
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc  \
# 1026        2013     2013           AK       Alaska
# 10934       2011     2011           KS       Kansas
# 41328       2015     2015           MI     Michigan
# 39193       2015     2015           DE     Delaware
# 741         2011     2011           AK       Alaska
#
#                                        Datasource                    Class  \
# 1026   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 10934  Behavioral Risk Factor Surveillance System    Fruits and Vegetables
# 41328  Behavioral Risk Factor Surveillance System        Physical Activity
# 39193  Behavioral Risk Factor Surveillance System        Physical Activity
# 741    Behavioral Risk Factor Surveillance System    Fruits and Vegetables
#
#                                   Topic  \
# 1026            Obesity / Weight Status
# 10934  Fruits and Vegetables - Behavior
# 41328      Physical Activity - Behavior
# 39193      Physical Activity - Behavior
# 741    Fruits and Vegetables - Behavior
#
#                                                 Question  Data_Value_Unit  \
# 1026   Percent of adults aged 18 years and older who ...              NaN
# 10934  Percent of adults who report consuming vegetab...              NaN
# 41328  Percent of adults who achieve at least 150 min...              NaN
# 39193  Percent of adults who achieve at least 150 min...              NaN
# 741    Percent of adults who report consuming fruit l...              NaN
#
#       Data_Value_Type  ...                               GeoLocation  ClassID  \
# 1026            Value  ...  (64.84507995700051, -147.72205903599973)      OWS
# 10934           Value  ...   (38.34774030000045, -98.20078122699965)       FV
# 41328           Value  ...    (44.6613195430005, -84.71439026999968)       PA
# 39193           Value  ...  (39.008830667000495, -75.57774116799965)       PA
# 741             Value  ...  (64.84507995700051, -147.72205903599973)       FV
#
#       TopicID QuestionID  DataValueTypeID  LocationID  \
# 1026     OWS1       Q036            VALUE           2
# 10934     FV1       Q019            VALUE          20
# 41328     PA1       Q044            VALUE          26
# 39193     PA1       Q043            VALUE          10
# 741       FV1       Q018            VALUE           2
#
#        StratificationCategory1        Stratification1  \
# 1026               Age (years)                35 - 44
# 10934                Education   High school graduate
# 41328                   Income      Less than $15,000
# 39193                Education  Less than high school
# 741                      Total                  Total
#
#       StratificationCategoryId1 StratificationID1
# 1026                      AGEYR         AGEYR3544
# 10934                       EDU         EDUHSGRAD
# 41328                       INC         INCLESS15
# 39193                       EDU             EDUHS
# 741                         OVR           OVERALL
#
# [5 rows x 33 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53392 entries, 0 to 53391
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   53392 non-null  int64
#  1   YearEnd                     53392 non-null  int64
#  2   LocationAbbr                53392 non-null  object
#  3   LocationDesc                53392 non-null  object
#  4   Datasource                  53392 non-null  object
#  5   Class                       53392 non-null  object
#  6   Topic                       53392 non-null  object
#  7   Question                    53392 non-null  object
#  8   Data_Value_Unit             0 non-null      float64
#  9   Data_Value_Type             53392 non-null  object
#  10  Data_Value                  48346 non-null  float64
#  11  Data_Value_Alt              48346 non-null  float64
#  12  Data_Value_Footnote_Symbol  5046 non-null   object
#  13  Data_Value_Footnote         5046 non-null   object
#  14  Low_Confidence_Limit        48346 non-null  float64
#  15  High_Confidence_Limit       48346 non-null  float64
#  16  Sample_Size                 48346 non-null  float64
#  17  Total                       1907 non-null   object
#  18  Age(years)                  11438 non-null  object
#  19  Education                   7628 non-null   object
#  20  Gender                      3814 non-null   object
#  21  Income                      13349 non-null  object
#  22  Race/Ethnicity              15256 non-null  object
#  23  GeoLocation                 52384 non-null  object
#  24  ClassID                     53392 non-null  object
#  25  TopicID                     53392 non-null  object
#  26  QuestionID                  53392 non-null  object
#  27  DataValueTypeID             53392 non-null  object
#  28  LocationID                  53392 non-null  int64
#  29  StratificationCategory1     53392 non-null  object
#  30  Stratification1             53392 non-null  object
#  31  StratificationCategoryId1   53392 non-null  object
#  32  StratificationID1           53392 non-null  object
# dtypes: float64(6), int64(3), object(24)
# memory usage: 13.4+ MB

# %%
dataset.describe(include = 'all')
# Out:
#            YearStart       YearEnd LocationAbbr          LocationDesc  \
# count   53392.000000  53392.000000        53392                 53392
# unique           NaN           NaN           55                    55
# top              NaN           NaN           UT  District of Columbia
# freq             NaN           NaN         1008                  1008
# mean     2013.281465   2013.281465          NaN                   NaN
# std         1.693300      1.693300          NaN                   NaN
# min      2011.000000   2011.000000          NaN                   NaN
# 25%      2012.000000   2012.000000          NaN                   NaN
# 50%      2013.000000   2013.000000          NaN                   NaN
# 75%      2015.000000   2015.000000          NaN                   NaN
# max      2016.000000   2016.000000          NaN                   NaN
#
#                                         Datasource              Class  \
# count                                        53392              53392
# unique                                           1                  3
# top     Behavioral Risk Factor Surveillance System  Physical Activity
# freq                                         53392              26628
# mean                                           NaN                NaN
# std                                            NaN                NaN
# min                                            NaN                NaN
# 25%                                            NaN                NaN
# 50%                                            NaN                NaN
# 75%                                            NaN                NaN
# max                                            NaN                NaN
#
#                                Topic  \
# count                          53392
# unique                             3
# top     Physical Activity - Behavior
# freq                           26628
# mean                             NaN
# std                              NaN
# min                              NaN
# 25%                              NaN
# 50%                              NaN
# 75%                              NaN
# max                              NaN
#
#                                                  Question  Data_Value_Unit  \
# count                                               53392              0.0
# unique                                                  9              NaN
# top     Percent of adults aged 18 years and older who ...              NaN
# freq                                                 8960              NaN
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#        Data_Value_Type  ...                               GeoLocation  \
# count            53392  ...                                     52384
# unique               1  ...                                        54
# top              Value  ...  (47.47531977900047, -100.11842104899966)
# freq             53392  ...                                      1008
# mean               NaN  ...                                       NaN
# std                NaN  ...                                       NaN
# min                NaN  ...                                       NaN
# 25%                NaN  ...                                       NaN
# 50%                NaN  ...                                       NaN
# 75%                NaN  ...                                       NaN
# max                NaN  ...                                       NaN
#
#         ClassID TopicID QuestionID  DataValueTypeID    LocationID  \
# count     53392   53392      53392            53392  53392.000000
# unique        3       3          9                1           NaN
# top          PA     PA1       Q036            VALUE           NaN
# freq      26628   26628       8960            53392           NaN
# mean        NaN     NaN        NaN              NaN     30.282215
# std         NaN     NaN        NaN              NaN     16.821318
# min         NaN     NaN        NaN              NaN      1.000000
# 25%         NaN     NaN        NaN              NaN     17.000000
# 50%         NaN     NaN        NaN              NaN     30.000000
# 75%         NaN     NaN        NaN              NaN     44.000000
# max         NaN     NaN        NaN              NaN     78.000000
#
#         StratificationCategory1        Stratification1  \
# count                     53392                  53392
# unique                        6                     28
# top              Race/Ethnicity  Less than high school
# freq                      15256                   1907
# mean                        NaN                    NaN
# std                         NaN                    NaN
# min                         NaN                    NaN
# 25%                         NaN                    NaN
# 50%                         NaN                    NaN
# 75%                         NaN                    NaN
# max                         NaN                    NaN
#
#        StratificationCategoryId1 StratificationID1
# count                      53392             53392
# unique                         6                28
# top                         RACE           RACEASN
# freq                       15256              1907
# mean                         NaN               NaN
# std                          NaN               NaN
# min                          NaN               NaN
# 25%                          NaN               NaN
# 50%                          NaN               NaN
# 75%                          NaN               NaN
# max                          NaN               NaN
#
# [11 rows x 33 columns]

# %%
dataset.shape
# Out:
# (53392, 33)

# %%
dataset.isnull().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# Datasource                        0
# Class                             0
# Topic                             0
# Question                          0
# Data_Value_Unit               53392
# Data_Value_Type                   0
# Data_Value                     5046
# Data_Value_Alt                 5046
# Data_Value_Footnote_Symbol    48346
# Data_Value_Footnote           48346
# Low_Confidence_Limit           5046
# High_Confidence_Limit          5046
# Sample_Size                    5046
# Total                         51485
# Age(years)                    41954
# Education                     45764
# Gender                        49578
# Income                        40043
# Race/Ethnicity                38136
# GeoLocation                    1008
# ClassID                           0
# TopicID                           0
# QuestionID                        0
# DataValueTypeID                   0
# LocationID                        0
# StratificationCategory1           0
# Stratification1                   0
# StratificationCategoryId1         0
# StratificationID1                 0
# dtype: int64

# %%
# remove redundant columns

all_columns = dataset.columns.copy()
columns_to_remove = ['Low_Confidence_Limit','High_Confidence_Limit ','YearEnd','Topic','Class','Datasource','Data_Value_Unit','QuestionID','ClassID','TopicID','DataValueTypeID','Data_Value_Type','Data_Value_Footnote_Symbol','Data_Value_Footnote','StratificationCategoryId1','StratificationID1']

needed_column = []
for i in range(len(all_columns)):
    if all_columns[i] not in columns_to_remove:
        needed_column.append(all_columns[i])
    
needed_column
# Out:
# ['YearStart',
#  'LocationAbbr',
#  'LocationDesc',
#  'Question',
#  'Data_Value',
#  'Data_Value_Alt',
#  'Sample_Size',
#  'Total',
#  'Age(years)',
#  'Education',
#  'Gender',
#  'Income',
#  'Race/Ethnicity',
#  'GeoLocation',
#  'LocationID',
#  'StratificationCategory1',
#  'Stratification1']

# %%
dataset = dataset[needed_column]

# %%
dataset.sample(5)
# Out:
#        YearStart LocationAbbr LocationDesc  \
# 50143       2016           WA   Washington
# 52437       2016           LA    Louisiana
# 51751       2016           WY      Wyoming
# 1924        2013           AZ      Arizona
# 30515       2011           UT         Utah
#
#                                                 Question  Data_Value  \
# 50143  Percent of adults aged 18 years and older who ...        27.4
# 52437  Percent of adults who engage in no leisure-tim...        15.9
# 51751  Percent of adults aged 18 years and older who ...        16.0
# 1924   Percent of adults who engage in no leisure-tim...        28.8
# 30515  Percent of adults aged 18 years and older who ...        35.4
#
#        Data_Value_Alt  Sample_Size Total Age(years) Education Gender  \
# 50143            27.4        835.0   NaN        NaN       NaN    NaN
# 52437            15.9       1149.0   NaN        NaN       NaN    NaN
# 51751            16.0        141.0   NaN    18 - 24       NaN    NaN
# 1924             28.8        535.0   NaN        NaN       NaN    NaN
# 30515            35.4         50.0   NaN        NaN       NaN    NaN
#
#                    Income      Race/Ethnicity  \
# 50143   Less than $15,000                 NaN
# 52437  $75,000 or greater                 NaN
# 51751                 NaN                 NaN
# 1924    Data not reported                 NaN
# 30515                 NaN  Non-Hispanic Black
#
#                                      GeoLocation  LocationID  \
# 50143   (47.52227862900048, -120.47001078999972)          53
# 52437    (31.31266064400046, -92.44568007099969)          22
# 51751   (43.23554134300048, -108.10983035299967)          56
# 1924   (34.865970280000454, -111.76381127699972)           4
# 30515  (39.360700171000474, -111.58713063499971)          49
#
#       StratificationCategory1     Stratification1
# 50143                  Income   Less than $15,000
# 52437                  Income  $75,000 or greater
# 51751             Age (years)             18 - 24
# 1924                   Income   Data not reported
# 30515          Race/Ethnicity  Non-Hispanic Black

# %%
# making use of the 2014 year data


dataset = dataset[dataset['YearStart']==2014]

# also seperating out data for just the obesity
dataset = dataset[dataset['Question'] == 'Percent of adults aged 18 years and older who have obesity']

# %%
dataset['LocationDesc'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida',
#        'District of Columbia', 'Georgia', 'Guam', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'National', 'Nebraska',
#        'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Puerto Rico', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
#        'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype=object)

# %%
# taking out dataset with just the states in the USA

dataset = dataset[~(dataset['LocationDesc']=='National')]
dataset = dataset[~(dataset['LocationDesc']=='Guam')]
dataset = dataset[~(dataset['LocationDesc']=='Puerto Rico')]
dataset['LocationDesc'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida',
#        'District of Columbia', 'Georgia', 'Hawaii', 'Idaho', 'Illinois',
#        'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine',
#        'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
# average percentage obesity 

average_percentage_obesity = round(dataset['Data_Value'].sum()/len(dataset['Data_Value']), 2)
average_percentage_obesity
# Out:
# 26.68

# %%
# creating differendt dataframe by gender, education, income, age


df_gender = dataset[(dataset['Stratification1']=='Male')|(dataset['Stratification1']=='Female')].reset_index(drop = True)
df_edu = dataset[dataset['StratificationCategory1']=='Education'].reset_index(drop = True)
df_income = dataset[dataset['StratificationCategory1']=='Income'].reset_index(drop = True)
df_race = dataset[dataset['StratificationCategory1']=='Race/Ethnicity'].reset_index(drop = True)
df_age = dataset[dataset['StratificationCategory1'] == 'Age (years)'].reset_index(drop = True)

# %%
# average_percentage_obesity by state

sorted_dataset = dataset.sort_values('LocationDesc', ascending = False)
sorted_dataset=sorted_dataset[['LocationAbbr','LocationDesc','Data_Value','Gender']]

sorted_dataset.groupby('LocationDesc').mean()
# Out:
#                       Data_Value
# LocationDesc
# Alabama                33.620000
# Alaska                 29.884615
# Arizona                28.962963
# Arkansas               37.136000
# California             25.051852
# Colorado               22.070370
# Connecticut            26.834615
# Delaware               30.228000
# District of Columbia   23.252000
# Florida                25.964000
# Georgia                29.556000
# Hawaii                 24.007692
# Idaho                  29.862500
# Illinois               28.588000
# Indiana                32.257692
# Iowa                   29.704000
# Kansas                 31.338462
# Kentucky               31.280000
# Louisiana              34.730769
# Maine                  28.158333
# Maryland               29.825926
# Massachusetts          24.196296
# Michigan               30.446154
# Minnesota              28.419231
# Mississippi            35.445455
# Missouri               30.711538
# Montana                27.487500
# Nebraska               31.684615
# Nevada                 27.919231
# New Hampshire          26.895833
# New Jersey             27.014815
# New Mexico             28.974074
# New York               27.068000
# North Carolina         29.680769
# North Dakota           33.052174
# Ohio                   32.381481
# Oklahoma               32.419231
# Oregon                 26.862500
# Pennsylvania           30.224000
# Rhode Island           26.850000
# South Carolina         30.830769
# South Dakota           31.112500
# Tennessee              32.052174
# Texas                  31.784615
# Utah                   26.076923
# Vermont                25.322727
# Virginia               28.557692
# Washington             27.485185
# West Virginia          35.986957
# Wisconsin              32.985185
# Wyoming                29.956000

# %%
by_state = sorted_dataset.groupby('LocationDesc').mean()
by_state = by_state.sort_values('Data_Value', ascending = False)
by_state
# Out:
#                       Data_Value
# LocationDesc
# Arkansas               37.136000
# West Virginia          35.986957
# Mississippi            35.445455
# Louisiana              34.730769
# Alabama                33.620000
# North Dakota           33.052174
# Wisconsin              32.985185
# Oklahoma               32.419231
# Ohio                   32.381481
# Indiana                32.257692
# Tennessee              32.052174
# Texas                  31.784615
# Nebraska               31.684615
# Kansas                 31.338462
# Kentucky               31.280000
# South Dakota           31.112500
# South Carolina         30.830769
# Missouri               30.711538
# Michigan               30.446154
# Delaware               30.228000
# Pennsylvania           30.224000
# Wyoming                29.956000
# Alaska                 29.884615
# Idaho                  29.862500
# Maryland               29.825926
# Iowa                   29.704000
# North Carolina         29.680769
# Georgia                29.556000
# New Mexico             28.974074
# Arizona                28.962963
# Illinois               28.588000
# Virginia               28.557692
# Minnesota              28.419231
# Maine                  28.158333
# Nevada                 27.919231
# Montana                27.487500
# Washington             27.485185
# New York               27.068000
# New Jersey             27.014815
# New Hampshire          26.895833
# Oregon                 26.862500
# Rhode Island           26.850000
# Connecticut            26.834615
# Utah                   26.076923
# Florida                25.964000
# Vermont                25.322727
# California             25.051852
# Massachusetts          24.196296
# Hawaii                 24.007692
# District of Columbia   23.252000
# Colorado               22.070370

# %%
plt.figure(figsize = (9, 12))
by_state[:20].plot(kind = "barh")
plt.show();

# %%
plt.figure(figsize = (9,12))
by_state[30:51].plot(kind = "barh")
plt.show();

# %%
# Out:
# array(['Less than $15,000', '$15,000 - $24,999', '$25,000 - $34,999',
#        '$35,000 - $49,999', '$50,000 - $74,999', '$75,000 or greater',
#        'Data not reported'], dtype=object)
